# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.96 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# Setup complete ✅ (16 CPUs, 15.6 GB RAM, 89.2/1006.9 GB disk)

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.6.0+cu124
# True
# NVIDIA GeForce RTX 4070

# %%
from ultralytics import YOLO
model=YOLO('yolov8n.pt')

# %%
results = model.train(data='content/minibusesMK1/data.yaml', epochs=64, imgsz=640, batch=8)
# Out:
# New https://pypi.org/project/ultralytics/8.3.102 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.96 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...

# %%
def show(link):
  predictions=model(link)
  predictions[0].show()

# %%
show("/home/dylanjitton/model_train/src/s13-MinibusesWeb.jpg")
# Out:
# image 1/1 /home/dylanjitton/model_train/src/s13-MinibusesWeb.jpg: 384x640 5 letreros, 33.5ms
# Speed: 2.7ms preprocess, 33.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=1122x626>

# %%
show("https://www.concejomunicipal.bo/wp-content/uploads/2023/03/s13-MinibusesWeb.jpg")
# Out:
# Found https://www.concejomunicipal.bo/wp-content/uploads/2023/03/s13-MinibusesWeb.jpg locally at s13-MinibusesWeb.jpg
# image 1/1 /home/dylanjitton/model_train/src/s13-MinibusesWeb.jpg: 384x640 5 letreros, 42.9ms
# Speed: 2.6ms preprocess, 42.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=1122x626>

# %%
show("/home/dylanjitton/model_train/src/images.jpeg")
# Out:
# image 1/1 /home/dylanjitton/model_train/src/images.jpeg: 480x640 2 letreros, 34.6ms
# Speed: 3.9ms preprocess, 34.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=259x194>

# %%
show("/home/dylanjitton/model_train/src/b_43523_choferes-de-minibuses-de-la-paz-aplican-incremento-de-bs-050-en-los-pasajes-1.png")
# Out:
# image 1/1 /home/dylanjitton/model_train/src/b_43523_choferes-de-minibuses-de-la-paz-aplican-incremento-de-bs-050-en-los-pasajes-1.png: 384x640 6 letreros, 32.5ms
# Speed: 2.0ms preprocess, 32.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=720x400>

# %%
model.save('/home/dylanjitton/model_train/src/content/minibus_sign_detector_MK_I.pt')

# %%
model.export(format="tflite")
# Out:
# Ultralytics 8.3.96 🚀 Python-3.12.3 torch-2.6.0+cu124 CPU (AMD Ryzen 7 5700X 8-Core Processor)
#
# PyTorch: starting from 'runs/detect/train11/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.9 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.49...
# ONNX: export success ✅ 0.6s, saved as 'runs/detect/train11/weights/best.onnx' (11.8 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.27.1...
# E0000 00:00:1743913042.401575    1619 cuda_dnn.cc:522] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.3.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# ...
